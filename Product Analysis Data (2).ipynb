# %% [markdown]
# # Product Sentiment Analysis
#
# - In this **Notebook** we have collected the Products of e-commerce companys like (**Amazon,Flipkart,Snapdeal**)
# - Products : **Books, Video Games,Camera & Photo Accessories, Beauty And Personal Care,Travel accessories.**

# %% [markdown]
# ### Import Libraries

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import datetime
import csv
import tweepy as tw
import numpy as np
import pandas as pd

# %%
consumer_key = 'LjKBLkIIpWEpqMgJ8VN9KmZ1l'
consumer_secret = '9ughUrd6fNQumas0ekT4K0AZYNoEawcAfTnDjjktGzdETHGV0V'
access_token = '1223254803926487041-kc8wl3AuTxPhrY2knZ23Qrz55vO9op'
access_token_secret = 'PEgT3rXnFELOhFmHpR5ZdLgDwHrsejEGttNwsKmqP6E0N'

# %%
auth = tw.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tw.API(auth,wait_on_rate_limit=True)

# %% [markdown]
# # Amazon Products
# ### Books

# %%
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%amazonIN -filter:retweets" + "Books -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_Amazon = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_Amazon
# Out:
# Enter how many tweets to search: 600
#                 user             location               source  \
# 0    VINODVA10591208                       Twitter for Android
# 1      idubeynirbhay     New Delhi, India      Twitter Web App
# 2           aliyaqut                India   Twitter for iPhone
# 3    VINODVA10591208                       Twitter for Android
# 4           PavanZzz                           Twitter Web App
# ..               ...                  ...                  ...
# 595      mewada_amit                           Twitter Web App
# 596   sophia_marie84        New York, USA  Twitter for Android
# 597   sandeepsonline  Mumbai, Maharashtra  Twitter for Android
# 598   Vishnu2194Aang    Palakkad, kerala       Twitter Web App
# 599  VinothK51329284       Chennai, India      Twitter Web App
#
#                                                   text
# 0    I have ordered myfitfuel gym power on Amazon o...
# 1       @amazonIN payment getting declined repeatedly.
# ...

# %%
tweet_Amazon.to_csv("Amazon_book.csv",index=False)

# %%
AmazonBook = pd.read_csv("Amazon_book.csv")
AmazonBook["product"] = "Books"
AmazonBook.to_csv("Amazon_book.csv", index=False)

# %% [markdown]
# ### Video Games

# %%
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%amazonIN -filter:retweets" + "Video Games -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_Amazon = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_Amazon
# Out:
# Enter how many tweets to search: 600
#                user               location               source  \
# 0   AnkitAroraEdits          Havana, Cuba   Twitter for Android
# 1          Venkey_3  Visakhapatnam ; India  Twitter for Android
# 2          Venkey_3  Visakhapatnam ; India  Twitter for Android
# 3         v2kumbhar                  India  Twitter for Android
# 4     sachinporwal6     Jhalrapatan, India  Twitter for Android
# ..              ...                    ...                  ...
# 81           m4jain                         Twitter for Android
# 82         gyagnesh              Ahmedabad  Twitter for Android
# 83  RaviKum75193040                         Twitter for Android
# 84      Champ_Sappy                  India  Twitter for Android
# 85      BirjuDamani                 mumbai  Twitter for Android
#
#                                                  text
# 0   Just so disappointed with @amazonIN \nAs you p...
# ...

# %%
tweet_Amazon.to_csv("Amazon_games.csv",index=False)

# %%
Amazongames = pd.read_csv("Amazon_games.csv")
Amazongames["product"] = "Video Games"
Amazongames.to_csv("Amazon_games.csv", index=False)

# %% [markdown]
# ### Camera & Photo Accessories

# %%
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%amazonIN -filter:retweets" + "Camera -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_Amazon = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_Amazon
# Out:
# Enter how many tweets to search: 600
#                 user             location               source  \
# 0    VINODVA10591208                       Twitter for Android
# 1      idubeynirbhay     New Delhi, India      Twitter Web App
# 2           aliyaqut                India   Twitter for iPhone
# 3    VINODVA10591208                       Twitter for Android
# 4           PavanZzz                           Twitter Web App
# ..               ...                  ...                  ...
# 595      mewada_amit                           Twitter Web App
# 596   sophia_marie84        New York, USA  Twitter for Android
# 597   sandeepsonline  Mumbai, Maharashtra  Twitter for Android
# 598   Vishnu2194Aang    Palakkad, kerala       Twitter Web App
# 599  VinothK51329284       Chennai, India      Twitter Web App
#
#                                                   text
# 0    I have ordered myfitfuel gym power on Amazon o...
# 1       @amazonIN payment getting declined repeatedly.
# ...

# %%
tweet_Amazon.to_csv("Amazon_camera.csv",index=False)

# %%
Amazoncamera = pd.read_csv("Amazon_camera.csv")
Amazoncamera["product"] = "Camera & Photo Accessories"
Amazoncamera.to_csv("Amazon_camera.csv", index=False)

# %% [markdown]
# ### Beauty And Personal Care

# %%
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%amazonIN -filter:retweets" + "Health Care -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_Amazon = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_Amazon
# Out:
# Enter how many tweets to search: 600
#                 user                      location               source  \
# 0         king_gagan                         Delhi   Twitter for iPhone
# 1       _Neha_Anand_               Dehradun, India      Twitter Web App
# 2        MrPanchanan                     Dhenkanal  Twitter for Android
# 3     guptaprakhar12                                Twitter for Android
# 4       inderrajvyas                                Twitter for Android
# ..               ...                           ...                  ...
# 300    MarathiBhaiya                       भारत 🇮🇳  Twitter for Android
# 301       Irfankool2                       Kolkata  Twitter for Android
# 302  KavindraKulkar1                                 Twitter for iPhone
# 303  underworldimage  Detroit Chicago Nuuk Bangkok      Twitter Web App
# 304      syednabeell                                Twitter for Android
#
#                                                   text
# ...

# %%
tweet_Amazon.to_csv("Amazon_care.csv",index=False)

# %%
Amazoncare = pd.read_csv("Amazon_care.csv")
Amazoncare["product"] = "Beauty & Care"
Amazoncare.to_csv("Amazon_care.csv", index=False)

# %% [markdown]
# ### Travel accessories.

# %%
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%amazonIN -filter:retweets" + "Travel -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_Amazon = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_Amazon
# Out:
# Enter how many tweets to search: 600
#                 user             location               source  \
# 0        srhonakatti                       Twitter for Android
# 1      sanand_satwik     Bengaluru, India      Twitter Web App
# 2    VINODVA10591208                       Twitter for Android
# 3      idubeynirbhay     New Delhi, India      Twitter Web App
# 4           aliyaqut                India   Twitter for iPhone
# ..               ...                  ...                  ...
# 595      __Monsees__         Kochi, India  Twitter for Android
# 596      mewada_amit                           Twitter Web App
# 597      mewada_amit                           Twitter Web App
# 598   sophia_marie84        New York, USA  Twitter for Android
# 599   sandeepsonline  Mumbai, Maharashtra  Twitter for Android
#
#                                                   text
# 0    @GyaanduLadka @amazonIN @AmazonHelp @amazon If...
# 1    My AMAZON PAY was disabled and I'm not getting...
# ...

# %%
tweet_Amazon.to_csv("Amazon_travel.csv",index=False)

# %%
Amazontravel = pd.read_csv("Amazon_travel.csv")
Amazontravel["product"] = "Travel accessories"
Amazontravel.to_csv("Amazon_travel.csv", index=False)

# %% [markdown]
# ### Loading data from csv Amazon_Final file

# %%
Amazon_Final1 = pd.concat([AmazonBook,Amazongames])
Amazon_Final2 = pd.concat([Amazoncamera,Amazoncare])
Amazon_Final3 = pd.concat([Amazon_Final1,Amazontravel])
Amazon_Final = pd.concat([Amazon_Final2,Amazon_Final3])
Amazon_Final.to_csv("Amazon_Final.csv",index = False)

# %%
amazon = pd.read_csv('Amazon_Final.csv')
amazon.head(3000)
# Out:
#                  user             location               source  \
# 0     VINODVA10591208                  NaN  Twitter for Android
# 1       idubeynirbhay     New Delhi, India      Twitter Web App
# 2            aliyaqut                India   Twitter for iPhone
# 3     VINODVA10591208                  NaN  Twitter for Android
# 4            PavanZzz                  NaN      Twitter Web App
# ...               ...                  ...                  ...
# 2186      __Monsees__         Kochi, India  Twitter for Android
# 2187      mewada_amit                  NaN      Twitter Web App
# 2188      mewada_amit                  NaN      Twitter Web App
# 2189   sophia_marie84        New York, USA  Twitter for Android
# 2190   sandeepsonline  Mumbai, Maharashtra  Twitter for Android
#
#                                                    text  \
# 0     I have ordered myfitfuel gym power on Amazon o...
# 1        @amazonIN payment getting declined repeatedly.
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # SnapDeal Products

# %%
# Books
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%snapdeal -filter:retweets" + "Books -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_snapdeal = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_snapdeal
# Out:
# Enter how many tweets to search: 600
#                 user               location               source  \
# 0            4psNews                             Twitter Web App
# 1       Chalta_Purja                  Earth   Twitter for iPhone
# 2      Snapdeal_Help                  India  OneDirect Suite - P
# 3     LondonRagIndia          Mumbai, India       Hootsuite Inc.
# 4          RealtyNXT                             Twitter Web App
# ..               ...                    ...                  ...
# 595    Snapdeal_Help                  India  OneDirect Suite - P
# 596    Snapdeal_Help                  India  OneDirect Suite - P
# 597    VishwasNavada  Bengaluru | Kundapura  Twitter for Android
# 598    Snapdeal_Help                  India  OneDirect Suite - P
# 599  swapnil_science                         Twitter for Android
#
#                                                   text
# 0    Snapdeal’s extensive reach in smaller cities a...
# ...

# %%
tweet_snapdeal.to_csv("Snap_book.csv",index=False)

# %%
SnapBook = pd.read_csv("Snap_book.csv")
SnapBook["product"] = "Books"
SnapBook.to_csv("Snap_book.csv", index=False)

# %%
# Video Games
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%snapdeal -filter:retweets" + "Video  -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_snapdeal = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_snapdeal
# Out:
# Enter how many tweets to search: 600
#                 user               location               source  \
# 0            4psNews                             Twitter Web App
# 1       Chalta_Purja                  Earth   Twitter for iPhone
# 2      Snapdeal_Help                  India  OneDirect Suite - P
# 3     LondonRagIndia          Mumbai, India       Hootsuite Inc.
# 4          RealtyNXT                             Twitter Web App
# ..               ...                    ...                  ...
# 595    Snapdeal_Help                  India  OneDirect Suite - P
# 596    Snapdeal_Help                  India  OneDirect Suite - P
# 597    VishwasNavada  Bengaluru | Kundapura  Twitter for Android
# 598    Snapdeal_Help                  India  OneDirect Suite - P
# 599  swapnil_science                         Twitter for Android
#
#                                                   text
# 0    Snapdeal’s extensive reach in smaller cities a...
# ...

# %%
tweet_snapdeal.to_csv("Snap_video.csv",index=False)

# %%
Snapvideo = pd.read_csv("Snap_video.csv")
Snapvideo["product"] = "Vedio Games"
Snapvideo.to_csv("Snap_video.csv", index=False)

# %%
# Camera & Photo Accessories
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%snapdeal -filter:retweets" + "Camera -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_snapdeal = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_snapdeal
# Out:
# Enter how many tweets to search: 600
#                 user               location               source  \
# 0            4psNews                             Twitter Web App
# 1       Chalta_Purja                  Earth   Twitter for iPhone
# 2      Snapdeal_Help                  India  OneDirect Suite - P
# 3     LondonRagIndia          Mumbai, India       Hootsuite Inc.
# 4          RealtyNXT                             Twitter Web App
# ..               ...                    ...                  ...
# 595    Snapdeal_Help                  India  OneDirect Suite - P
# 596    Snapdeal_Help                  India  OneDirect Suite - P
# 597    VishwasNavada  Bengaluru | Kundapura  Twitter for Android
# 598    Snapdeal_Help                  India  OneDirect Suite - P
# 599  swapnil_science                         Twitter for Android
#
#                                                   text
# 0    Snapdeal’s extensive reach in smaller cities a...
# ...

# %%
tweet_snapdeal.to_csv("Snap_camera.csv",index=False)

# %%
Snapcamera = pd.read_csv("Snap_camera.csv")
Snapcamera["product"] = "Camera & Photo Accessories"
Snapcamera.to_csv("Snap_camera.csv", index=False)

# %%
# Beauty And Personal Care
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%snapdeal -filter:retweets" + "Health Care -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_snapdeal = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_snapdeal
# Out:
# Enter how many tweets to search: 600
#                user location               source  \
# 0   Rakeshm61738514           Twitter for Android
# 1          Rickyist   punjab  Twitter for Android
# 2          Rickyist   punjab  Twitter for Android
# 3          Rickyist   punjab  Twitter for Android
# 4             eu3or            Twitter for iPhone
# ..              ...      ...                  ...
# 65            eu3or            Twitter for iPhone
# 66            eu3or            Twitter for iPhone
# 67            eu3or            Twitter for iPhone
# 68            eu3or            Twitter for iPhone
# 69            eu3or            Twitter for iPhone
#
#                                                  text
# 0   Hello sir repeleshment kiye Snapdeal Jamshedpu...
# 1   Don’t buy anything from @snapdeal worst delive...
# 2   Don’t buy anything from @snapdeal worst delive...
# 3   Don’t buy anything from @snapdeal worst delive...
# ...

# %%
tweet_snapdeal.to_csv("Snap_care.csv",index=False)

# %%
Snapcare = pd.read_csv("Snap_care.csv")
Snapcare["product"] = "Beauty And Personal Care"
Snapcare.to_csv("Snap_care.csv", index=False)

# %%
# Travel accessories
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%snapdeal -filter:retweets" + "Travel -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_snapdeal = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_snapdeal
# Out:
# Enter how many tweets to search: 600
#                 user           location               source  \
# 0      Snapdeal_Help              India  OneDirect Suite - P
# 1           hemantmx         Right Here  Twitter for Android
# 2      Snapdeal_Help              India  OneDirect Suite - P
# 3           hemantmx         Right Here  Twitter for Android
# 4    EDTimesOfficial              India  Twitter for Android
# ..               ...                ...                  ...
# 595       addaspark1                         Twitter Web App
# 596       addaspark1                         Twitter Web App
# 597          copazad  Chandigarh, India  Twitter for Android
# 598     altmodaindia              Noida               Buffer
# 599    Snapdeal_Help              India  OneDirect Suite - P
#
#                                                   text
# 0    @hemantmx Apologies for this experience, pleas...
# 1    1.orderd jacket on 27th dec\n2. 1st jan app sh...
# ...

# %%
tweet_snapdeal.to_csv("Snap_travel.csv",index=False)

# %%
Snaptravel = pd.read_csv("Snap_travel.csv")
Snaptravel["product"] = "Travel accessories"
Snaptravel.to_csv("Snap_travel.csv", index=False)

# %%
# Loading data from csv Amazon_Final file
Snapdeal_Final1 = pd.concat([SnapBook,Snapvideo])
Snapdeal_Final2 = pd.concat([Snapcamera,Snapcare])
Snapdeal_Final3 = pd.concat([Snapdeal_Final1,Snaptravel])
Snapdeal_Final = pd.concat([Snapdeal_Final2,Snapdeal_Final3])
Snapdeal_Final.to_csv("Snapdeal_Final.csv",index = False)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Flipkart Products

# %%
# Travel accessories
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%flipkart -filter:retweets" + "Book -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_flipkart = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_flipkart
# Out:
# Enter how many tweets to search: 600
#                 user          location               source  \
# 0         It_is_HitS                    Twitter for Android
# 1      TweetTheDeals                                  IFTTT
# 2    DealBeeOfficial             India      Twitter Web App
# 3    DealBeeOfficial             India      Twitter Web App
# 4          DeviceNXT  New Delhi, India      Twitter Web App
# ..               ...               ...                  ...
# 595  kanchan52335498                    Twitter for Android
# 596    Moksh52695693                        Twitter Web App
# 597    RamlakshmanBY                        Twitter Web App
# 598     GajariaRohit                    Twitter for Android
# 599  flipkartsupport             India    SocialCS Flipkart
#
#                                                   text
# 0    @KanishakGoyal @belwether_ankur @GemsOfBollywo...
# 1    Flipkart Answers\n\nFake Or Not\nCheetah is fa...
# ...

# %%
tweet_flipkart.to_csv("flip_book.csv",index=False)

# %%
flipbook = pd.read_csv("flip_book.csv")
flipbook["product"] = "Books"
flipbook.to_csv("flip_book.csv", index=False)

# %%
# Video Games
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%flipkart -filter:retweets" + "Games -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_flipkart = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_flipkart
# Out:
# Enter how many tweets to search: 600
#                 user                        location               source  \
# 0    flipkartsupport                           India    SocialCS Flipkart
# 1         DekhReview                  Kolkata, India      Twitter Web App
# 2     Aithani_ganesh                  Gurgaon, India   Twitter for iPhone
# 3       DealsDhamaka                                      Twitter Web App
# 4    Amazingdeals360                           India  Twitter for Android
# ..               ...                             ...                  ...
# 595     anup_bilchod            Dublin City, Ireland  Twitter for Android
# 596       meYuvraj09        Kodathi, Bengaluru South      Twitter Web App
# 597    Shyam02473344                                      Twitter Web App
# 598       Gadgets360  India's most popular tech site            TweetDeck
# 599     DEV143RAJPUT                       NEW DELHI  Twitter for Android
#
# ...

# %%
tweet_flipkart.to_csv("flip_games.csv",index=False)

# %%
flipgame = pd.read_csv("flip_games.csv")
flipgame["product"] = "Video games"
flipgame.to_csv("flip_games.csv", index=False)

# %%
# Camera & Photo Accessories
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%flipkart -filter:retweets" + "Camera -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_flipkart = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_flipkart
# Out:
# Enter how many tweets to search: 600
#                 user        location               source  \
# 0       DealsDhamaka                      Twitter Web App
# 1    panaromascandle                  Twitter for Android
# 2    Amazingdeals360           India  Twitter for Android
# 3    DealBeeOfficial           India             Deal.Bee
# 4        dealztrendz           India   Twitter for iPhone
# ..               ...             ...                  ...
# 595    iShivaTronics          Mumbai      Twitter Web App
# 596     chayangarg2f  Gurgaon, India   Twitter for iPhone
# 597         7Deals24       Hyderabad      Twitter Web App
# 598    Shyam02473344                      Twitter Web App
# 599   TheRightPath20                      Twitter Web App
#
#                                                   text
# 0    SUPER OFFER FOR KIDS - Kellogg's Chocos Moons ...
# 1    Tip of the Day: For votive and glass filled ca...
# 2    UPCOMING | Apple Iphone SE 2020\n\n₹27,999\n\n...
# ...

# %%
tweet_flipkart.to_csv("flip_camera.csv",index=False)

# %%
flipcamera = pd.read_csv("flip_camera.csv")
flipcamera["product"] = "Camera & Photo Accessories"
flipcamera.to_csv("flip_camera.csv", index=False)

# %%
# Beauty And Personal Care
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%flipkart -filter:retweets" + "Health Care -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_flipkart = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_flipkart
# Out:
# Enter how many tweets to search: 600
#                 user                     location               source  \
# 0    Dharmen03014197                                   Twitter Web App
# 1      Aryan97520465                       Jaipur  Twitter for Android
# 2          rohit9060               Lucknow, India      Twitter Web App
# 3        actorTanmay                        Thane      Twitter Web App
# 4       DealsDhamaka                                   Twitter Web App
# ..               ...                          ...                  ...
# 414    sunny002kumar                                   Twitter Web App
# 415          tkphani             Hyderabad, India  Twitter for Android
# 416     TinkuSharma1                         Pune   Twitter for iPhone
# 417         Drakash_                               Twitter for Android
# 418        sk739dhak  Jarang Rampur, Bihar, India      Twitter Web App
#
#                                                   text
# ...

# %%
tweet_flipkart.to_csv("flip_care.csv",index=False)

# %%
flipcare = pd.read_csv("flip_care.csv")
flipcare["product"] = "Beauty And Personal Care"
flipcare.to_csv("flip_care.csv", index=False)

# %%
# Travel accessories
NoOfTerms = int(input("Enter how many tweets to search: "))
#new_search = searchTerm + " -filter:retweets""
#new_search
new_search = "%flipkart -filter:retweets" + "Travel -filter:retweets"

tweets = tw.Cursor(api.search,
                       q=new_search,tweet_mode='extended',
                       lang="en").items(NoOfTerms)

users_locs = [[tweet.user.screen_name, tweet.user.location ,tweet.source,tweet.full_text] for tweet in tweets ]
users_locs
tweet_flipkart = pd.DataFrame(data=users_locs, 
                    columns=["user", "location","source","text"])
tweet_flipkart
# Out:
# Enter how many tweets to search: 600
#                 user       location               source  \
# 0            13dev_p  Kanpur, India  Twitter for Android
# 1     AnjalliRathour                  Twitter for iPhone
# 2    Amazingdeals360          India  Twitter for Android
# 3    Amazingdeals360          India  Twitter for Android
# 4    Amazingdeals360          India  Twitter for Android
# ..               ...            ...                  ...
# 595      RajRoshan44                 Twitter for Android
# 596      RajRoshan44                 Twitter for Android
# 597      RajRoshan44                 Twitter for Android
# 598  SachdevaRajesh6                 Twitter for Android
# 599    advshubham005          Delhi  Twitter for Android
#
#                                                   text
# 0    Hey @Flipkart @flipkartsupport I have my birth...
# 1    @Flipkart @flipkartsupport - I am a vintage cu...
# 2    UPCOMING | Samsung A21s\n\nFrom ₹13,999\n\nhtt...
# ...

# %%
tweet_flipkart.to_csv("flip_travel.csv",index=False)

# %%
fliptravel = pd.read_csv("flip_travel.csv")
fliptravel["product"] = "Travel accessories"
fliptravel.to_csv("flip_travel.csv", index=False)

# %%
Flipkart_Final1 = pd.concat([flipbook,flipgame])
Flipkart_Final2 = pd.concat([flipcamera,flipcare])
Flipkart_Final3 = pd.concat([Flipkart_Final1,fliptravel])
Flipkart_Final = pd.concat([Flipkart_Final2,Flipkart_Final3])
Flipkart_Final.to_csv("Flipkart_final.csv",index = False)

# %%
flipkart = pd.read_csv('Flipkart_final.csv')
flipkart.head(3000)
# Out:
#                  user location               source  \
# 0        DealsDhamaka      NaN      Twitter Web App
# 1     panaromascandle      NaN  Twitter for Android
# 2     Amazingdeals360    India  Twitter for Android
# 3     DealBeeOfficial    India             Deal.Bee
# 4         dealztrendz    India   Twitter for iPhone
# ...               ...      ...                  ...
# 2814      RajRoshan44      NaN  Twitter for Android
# 2815      RajRoshan44      NaN  Twitter for Android
# 2816      RajRoshan44      NaN  Twitter for Android
# 2817  SachdevaRajesh6      NaN  Twitter for Android
# 2818    advshubham005    Delhi  Twitter for Android
#
#                                                    text  \
# 0     SUPER OFFER FOR KIDS - Kellogg's Chocos Moons ...
# 1     Tip of the Day: For votive and glass filled ca...
# 2     UPCOMING | Apple Iphone SE 2020\n\n₹27,999\n\n...
# 3     KENSTAR Fresh 10L Water Heater at ₹4,125\n\nht...
# ...

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
